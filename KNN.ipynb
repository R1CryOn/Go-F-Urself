# %%
import pandas as pd
cancer = pd.read_csv('wbc.csv')
cancer.head(2)
# Out:
#        id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0  842302         M  ...                  0.11890          NaN
# 1  842517         M  ...                  0.08902          NaN
#
# [2 rows x 33 columns]

# %%
cancer.drop(['Unnamed: 32','id'],1,inplace=True)
cancer.head(2)
# Out:
#   diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         M        17.99  ...          0.4601                  0.11890
# 1         M        20.57  ...          0.2750                  0.08902
#
# [2 rows x 31 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
cancer['diagnosis'] = le.fit_transform(cancer['diagnosis'])
cancer.head(2)
# Out:
#    diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0          1        17.99  ...          0.4601                  0.11890
# 1          1        20.57  ...          0.2750                  0.08902
#
# [2 rows x 31 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = round(cancer.corr(),2)
corr
# Out:
#                          diagnosis  ...  fractal_dimension_worst
# diagnosis                     1.00  ...                     0.32
# radius_mean                   0.73  ...                     0.01
# texture_mean                  0.42  ...                     0.12
# perimeter_mean                0.74  ...                     0.05
# area_mean                     0.71  ...                     0.00
# smoothness_mean               0.36  ...                     0.50
# compactness_mean              0.60  ...                     0.69
# concavity_mean                0.70  ...                     0.51
# concave points_mean           0.78  ...                     0.37
# symmetry_mean                 0.33  ...                     0.44
# fractal_dimension_mean       -0.01  ...                     0.77
# radius_se                     0.57  ...                     0.05
# texture_se                   -0.01  ...                    -0.05
# perimeter_se                  0.56  ...                     0.09
# area_se                       0.55  ...                     0.02
# smoothness_se                -0.07  ...                     0.10
# compactness_se                0.29  ...                     0.59
# concavity_se                  0.25  ...                     0.44
# concave points_se             0.41  ...                     0.31
# symmetry_se                  -0.01  ...                     0.08
# fractal_dimension_se          0.08  ...                     0.59
# radius_worst                  0.78  ...                     0.09
# texture_worst                 0.46  ...                     0.22
# perimeter_worst               0.78  ...                     0.14
# area_worst                    0.73  ...                     0.08
# smoothness_worst              0.42  ...                     0.62
# compactness_worst             0.59  ...                     0.81
# concavity_worst               0.66  ...                     0.69
# concave points_worst          0.79  ...                     0.51
# symmetry_worst                0.42  ...                     0.54
# fractal_dimension_worst       0.32  ...                     1.00
#
# [31 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split, cross_val_score

# %%
feature = cancer.drop('diagnosis',1)
diagnosis = cancer['diagnosis']

# %%
X_train,X_test,y_train,y_test = train_test_split(feature,diagnosis,test_size=0.2,random_state=1111)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=2)

# %%
cv = cross_val_score(knn,X_train,y_train,cv=5)
cv
# Out:
# array([0.9010989 , 0.93406593, 0.92307692, 0.95604396, 0.89010989])

# %%
cv.mean()
# Out:
# 0.9208791208791208

# %%
knn.fit(X_train,y_train)
knn.score(X_train,y_train)
# Out:
# 0.9472527472527472

# %%
knn.score(X_test,y_test)
# Out:
# 0.9210526315789473

# %%
pred = knn.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,pred)
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(cm,annot=True,fmt='g',cmap='Wistia')
plt.xlabel('Predicted Value')
plt.ylabel('Actual Value')
plt.show()

# %%
from sklearn.metrics import classification_report
cr = classification_report(y_test,pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94        65
#            1       1.00      0.82      0.90        49
#
#     accuracy                           0.92       114
#    macro avg       0.94      0.91      0.92       114
# weighted avg       0.93      0.92      0.92       114
